# %%
import pandas as pd
import math
df=pd.read_csv("survey_results_public.csv")
df_schema=pd.read_csv("survey_results_schema.csv")
people={"first":["Rajat","Corey","John"],
        "last":["Gupta","Sch","Doe"],
        "email":["RajatGupta@email.com","corey@email.com","john@email.com"]}
df2=pd.DataFrame(people)

# %%
df["ConvertedComp"].mean()
# Out:
# 103756.05014961446

# %%
df["ConvertedComp"].median()
# Out:
# 54049.0

# %%
df.median()
# Out:
# Respondent       32231.0
# Age                 29.0
# CompTotal        63000.0
# ConvertedComp    54049.0
# WorkWeekHrs         40.0
# dtype: float64

# %%
df.max()
# Out:
# Respondent        6.563900e+04
# Age               2.790000e+02
# CompTotal        1.111111e+247
# ConvertedComp     2.000000e+06
# WorkWeekHrs       4.750000e+02
# dtype: float64

# %%
df["Age"].max()
# Out:
# 279.0

# %%
f=df["Age"]==279

# %%
df[f]
# Out:
#        Respondent                      MainBranch Hobbyist    Age Age1stCode  \
# 14375       14419  I am a developer by profession      Yes  279.0         16
#
#       CompFreq  CompTotal  ConvertedComp      Country   CurrencyDesc  ...  \
# 14375   Yearly    49000.0        52968.0  Netherlands  European Euro  ...
#
#       SurveyEase SurveyLength Trans  \
# 14375       Easy     Too long    No
#
#                                           UndergradMajor  \
# 14375  Computer science, computer engineering, or sof...
#
#       WebframeDesireNextYear WebframeWorkedWith  \
# 14375                    NaN           React.js
#
#                                  WelcomeChange WorkWeekHrs YearsCode  \
# 14375  Just as welcome now as I felt last year        40.0         7
#
#       YearsCodePro
# 14375            3
#
# [1 rows x 61 columns]

# %%
df.describe()
# Out:
#          Respondent           Age      CompTotal  ConvertedComp   WorkWeekHrs
# count  64461.000000  45446.000000   3.482600e+04   3.475600e+04  41151.000000
# mean   32554.079738     30.834111  3.190464e+242   1.037561e+05     40.782174
# std    18967.442360      9.585392            inf   2.268853e+05     17.816383
# min        1.000000      1.000000   0.000000e+00   0.000000e+00      1.000000
# 25%    16116.000000     24.000000   2.000000e+04   2.464800e+04     40.000000
# 50%    32231.000000     29.000000   6.300000e+04   5.404900e+04     40.000000
# 75%    49142.000000     35.000000   1.250000e+05   9.500000e+04     44.000000
# max    65639.000000    279.000000  1.111111e+247   2.000000e+06    475.000000

# %%
df["ConvertedComp"].describe()
# Out:
# count    3.475600e+04
# mean     1.037561e+05
# std      2.268853e+05
# min      0.000000e+00
# 25%      2.464800e+04
# 50%      5.404900e+04
# 75%      9.500000e+04
# max      2.000000e+06
# Name: ConvertedComp, dtype: float64

# %%
df.count()
# Out:
# Respondent            64461
# MainBranch            64162
# Hobbyist              64416
# Age                   45446
# Age1stCode            57900
#                       ...
# WebframeWorkedWith    42279
# WelcomeChange         52683
# WorkWeekHrs           41151
# YearsCode             57684
# YearsCodePro          46349
# Length: 61, dtype: int64

# %%
df["ConvertedComp"].count()
# Out:
# 34756

# %%
df["ConvertedComp"].value_counts()
# Out:
# 120000.0     341
# 100000.0     306
# 150000.0     277
# 2000000.0    258
# 1000000.0    258
#             ...
# 102700.0       1
# 68721.0        1
# 96250.0        1
# 38456.0        1
# 21487.0        1
# Name: ConvertedComp, Length: 6958, dtype: int64

# %%
df["Hobbyist"].value_counts()
# Out:
# Yes    50388
# No     14028
# Name: Hobbyist, dtype: int64

# %%
pd.set_option("display.max_columns",61)

# %%
df
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1                     I am a developer by profession      Yes
# 1               2                     I am a developer by profession       No
# 2               3                        I code primarily as a hobby      Yes
# 3               4                     I am a developer by profession      Yes
# 4               5  I used to be a developer by profession, but no...      Yes
# ...           ...                                                ...      ...
# 64456       64858                                                NaN      Yes
# 64457       64867                                                NaN      Yes
# 64458       64898                                                NaN      Yes
# 64459       64925                                                NaN      Yes
# 64460       65112                                                NaN      Yes
#
# ...

# %%
df_schema
# Out:
#                 Column                                       QuestionText
# 0           Respondent  Randomized respondent ID number (not in order ...
# 1           MainBranch  Which of the following options best describes ...
# 2             Hobbyist                            Do you code as a hobby?
# 3                  Age  What is your age (in years)? If you prefer not...
# 4           Age1stCode  At what age did you write your first line of c...
# ..                 ...                                                ...
# 56  WebframeWorkedWith  Which web frameworks have you done extensive d...
# 57       WelcomeChange  Compared to last year, how welcome do you feel...
# 58         WorkWeekHrs  On average, how many hours per week do you wor...
# 59           YearsCode  Including any education, how many years have y...
# 60        YearsCodePro  NOT including education, how many years have y...
#
# [61 rows x 2 columns]

# %%
df_schema.set_index("Column",inplace=True)

# %%
pd.set_option("display.max_row",61)

# %%
df_schema
# Out:
#                                                                    QuestionText
# Column
# Respondent                    Randomized respondent ID number (not in order ...
# MainBranch                    Which of the following options best describes ...
# Hobbyist                                                Do you code as a hobby?
# Age                           What is your age (in years)? If you prefer not...
# Age1stCode                    At what age did you write your first line of c...
# CompFreq                       Is that compensation weekly, monthly, or yearly?
# CompTotal                     What is your current total compensation (salar...
# ConvertedComp                 Salary converted to annual USD salaries using ...
# Country                                                      Where do you live?
# CurrencyDesc                  Which currency do you use day-to-day? If your ...
# CurrencySymbol                Which currency do you use day-to-day? If your ...
# ...

# %%
df_schema["QuestionText"]["SOPartFreq"]
# Out:
# 'How frequently would you say you participate in Q&A on Stack Overflow? By participate we mean ask, answer, vote for, or comment on questions.'

# %%
df["SOPartFreq"].value_counts()
# Out:
# Less than once per month or monthly                   20432
# I have never participated in Q&A on Stack Overflow    10427
# A few times per month or weekly                        8317
# A few times per week                                   4193
# Daily or almost daily                                  2198
# Multiple times per day                                 1225
# Name: SOPartFreq, dtype: int64

# %%
df["SOPartFreq"].value_counts(normalize=True)
# Out:
# Less than once per month or monthly                   0.436656
# I have never participated in Q&A on Stack Overflow    0.222837
# A few times per month or weekly                       0.177744
# A few times per week                                  0.089609
# Daily or almost daily                                 0.046974
# Multiple times per day                                0.026180
# Name: SOPartFreq, dtype: float64

# %%
df["Country"].value_counts()
# Out:
# United States     12469
# India              8403
# United Kingdom     3896
# Germany            3890
# Canada             2191
#                   ...
# Lesotho               1
# Kiribati              1
# Nauru                 1
# Grenada               1
# Saint Lucia           1
# Name: Country, Length: 183, dtype: int64

# %%
df.groupby(["Country"])

# %%
country_grp=df.groupby(["Country"])

# %%
country_grp.get_group("India")
# Out:
#        Respondent                              MainBranch Hobbyist   Age  \
# 6               7          I am a developer by profession      Yes   NaN
# 21             22          I am a developer by profession      Yes   NaN
# 57             58          I am a developer by profession      Yes   NaN
# 62             63  I am a student who is learning to code      Yes  21.0
# 147           149          I am a developer by profession      Yes  36.0
# ...           ...                                     ...      ...   ...
# 64391       54757                                     NaN      Yes   NaN
# 64398       55407                                     NaN      Yes   NaN
# 64439       62464                                     NaN      Yes   NaN
# 64442       62954                                     NaN      Yes   NaN
# 64452       64236                                     NaN      Yes   NaN
#
#       Age1stCode CompFreq   CompTotal  ConvertedComp Country  \
# ...

# %%
df[df["Country"]=="India"]
# Out:
#        Respondent                              MainBranch Hobbyist   Age  \
# 6               7          I am a developer by profession      Yes   NaN
# 21             22          I am a developer by profession      Yes   NaN
# 57             58          I am a developer by profession      Yes   NaN
# 62             63  I am a student who is learning to code      Yes  21.0
# 147           149          I am a developer by profession      Yes  36.0
# ...           ...                                     ...      ...   ...
# 64391       54757                                     NaN      Yes   NaN
# 64398       55407                                     NaN      Yes   NaN
# 64439       62464                                     NaN      Yes   NaN
# 64442       62954                                     NaN      Yes   NaN
# 64452       64236                                     NaN      Yes   NaN
#
#       Age1stCode CompFreq   CompTotal  ConvertedComp Country  \
# ...

# %%
filt=df["Country"]=="India"

# %%
df[filt]
# Out:
#        Respondent                              MainBranch Hobbyist   Age  \
# 6               7          I am a developer by profession      Yes   NaN
# 21             22          I am a developer by profession      Yes   NaN
# 57             58          I am a developer by profession      Yes   NaN
# 62             63  I am a student who is learning to code      Yes  21.0
# 147           149          I am a developer by profession      Yes  36.0
# ...           ...                                     ...      ...   ...
# 64391       54757                                     NaN      Yes   NaN
# 64398       55407                                     NaN      Yes   NaN
# 64439       62464                                     NaN      Yes   NaN
# 64442       62954                                     NaN      Yes   NaN
# 64452       64236                                     NaN      Yes   NaN
#
#       Age1stCode CompFreq   CompTotal  ConvertedComp Country  \
# ...

# %%
df.loc[filt,"SOVisitFreq"].value_counts()
# Out:
# Multiple times per day                                2649
# Daily or almost daily                                 2202
# A few times per week                                  1112
# A few times per month or weekly                        625
# Less than once per month or monthly                    173
# I have never visited Stack Overflow (before today)      38
# Name: SOVisitFreq, dtype: int64

# %%
df.loc[filt]["SOVisitFreq"].value_counts()
# Out:
# Multiple times per day                                2649
# Daily or almost daily                                 2202
# A few times per week                                  1112
# A few times per month or weekly                        625
# Less than once per month or monthly                    173
# I have never visited Stack Overflow (before today)      38
# Name: SOVisitFreq, dtype: int64

# %%
df[filt]["SOVisitFreq"].value_counts()
# Out:
# Multiple times per day                                2649
# Daily or almost daily                                 2202
# A few times per week                                  1112
# A few times per month or weekly                        625
# Less than once per month or monthly                    173
# I have never visited Stack Overflow (before today)      38
# Name: SOVisitFreq, dtype: int64

# %%
country_grp["SOVisitFreq"].value_counts()
# Out:
# Country      SOVisitFreq
# Afghanistan  Daily or almost daily                                 12
#              Multiple times per day                                12
#              A few times per week                                  10
#              A few times per month or weekly                        6
#              I have never visited Stack Overflow (before today)     4
#                                                                    ..
# Zimbabwe     A few times per month or weekly                        8
#              Daily or almost daily                                  8
#              Multiple times per day                                 7
#              A few times per week                                   3
#              Less than once per month or monthly                    2
# Name: SOVisitFreq, Length: 761, dtype: int64

# %%
country_grp["SOVisitFreq"].value_counts().loc["India"]
# Out:
# SOVisitFreq
# Multiple times per day                                2649
# Daily or almost daily                                 2202
# A few times per week                                  1112
# A few times per month or weekly                        625
# Less than once per month or monthly                    173
# I have never visited Stack Overflow (before today)      38
# Name: SOVisitFreq, dtype: int64

# %%
country_grp["SOVisitFreq"].value_counts(normalize=True).loc["India"]
# Out:
# SOVisitFreq
# Multiple times per day                                0.389616
# Daily or almost daily                                 0.323871
# A few times per week                                  0.163553
# A few times per month or weekly                       0.091925
# Less than once per month or monthly                   0.025445
# I have never visited Stack Overflow (before today)    0.005589
# Name: SOVisitFreq, dtype: float64

# %%
country_grp["ConvertedComp"].median()
# Out:
# Country
# Afghanistan                             15163.5
# Albania                                 15900.0
# Algeria                                  9432.0
# Andorra                                 88640.0
# Angola                                   5292.0
#                                          ...
# Venezuela, Bolivarian Republic of...     3600.0
# Viet Nam                                10344.0
# Yemen                                   36000.0
# Zambia                                   5452.0
# Zimbabwe                                 7200.0
# Name: ConvertedComp, Length: 183, dtype: float64

# %%
country_grp["ConvertedComp"].median().loc["Germany"]
# Out:
# 62697.0

# %%
country_grp["ConvertedComp"].agg(["median","mean"])
# Out:
#                                        median           mean
# Country
# Afghanistan                           15163.5  148290.125000
# Albania                               15900.0   25611.000000
# Algeria                                9432.0   10362.812500
# Andorra                               88640.0   88640.000000
# Angola                                 5292.0    5292.000000
# ...                                       ...            ...
# Venezuela, Bolivarian Republic of...   3600.0    6280.611111
# Viet Nam                              10344.0   28342.605769
# Yemen                                 36000.0   36000.000000
# Zambia                                 5452.0   17506.400000
# Zimbabwe                               7200.0   26338.181818
#
# [183 rows x 2 columns]

# %%
country_grp["ConvertedComp"].agg(["mean","median"]).loc["India"]
# Out:
# mean      28751.271364
# median    10056.000000
# Name: India, dtype: float64

# %%
filt=df["Country"]=="India"

# %%
df.loc[filt,"LanguageWorkedWith"]
# Out:
# 6                                  C#;HTML/CSS;PHP
# 21                                     Java;Python
# 57                    C#;JavaScript;SQL;TypeScript
# 62           C;C++;HTML/CSS;Java;JavaScript;Python
# 147                 Bash/Shell/PowerShell;C++;Perl
#                            ...
# 64391    C;HTML/CSS;Java;JavaScript;PHP;Python;SQL
# 64398                                          NaN
# 64439                                          NaN
# 64442                                          SQL
# 64452                                          NaN
# Name: LanguageWorkedWith, Length: 8403, dtype: object

# %%
df.loc[filt,"LanguageWorkedWith"].str.contains("Python")
# Out:
# 6        False
# 21        True
# 57       False
# 62        True
# 147      False
#          ...
# 64391     True
# 64398      NaN
# 64439      NaN
# 64442    False
# 64452      NaN
# Name: LanguageWorkedWith, Length: 8403, dtype: object

# %%
df.loc[filt,"LanguageWorkedWith"].str.contains("Python").sum()
# Out:
# 2670

# %%
country_grp["LanguageWorkedWith"].str.contains("Python").sum().loc["India"]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-45-2f8a5790ad5c> in <module>
# ----> 1 country_grp["LanguageWorkedWith"].str.contains("Python").sum().loc["India"]
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in __getattr__(self, attr)
#     561             return self[attr]
#     562         if hasattr(self.obj, attr):
# --> 563             return self._make_wrapper(attr)
#     564
#     565         raise AttributeError(
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in _make_wrapper(self, name)
#     602                 "using the 'apply' method".format(kind, name, type(self).__name__)
#     603             )
# --> 604             raise AttributeError(msg)
#     605
#     606         self._set_group_selection()
#
# AttributeError: Cannot access attribute 'str' of 'SeriesGroupBy' objects, try using the 'apply' method

# %%
country_grp["LanguageWorkedWith"].apply(lambda x:x)
# Out:
# 0                                   C#;HTML/CSS;JavaScript
# 1                                         JavaScript;Swift
# 2                                 Objective-C;Python;Swift
# 3                                                      NaN
# 4                                        HTML/CSS;Ruby;SQL
#                                ...
# 64456                                                  NaN
# 64457    Assembly;Bash/Shell/PowerShell;C;C#;C++;Dart;G...
# 64458                                                  NaN
# 64459                                             HTML/CSS
# 64460                      C#;HTML/CSS;Java;JavaScript;SQL
# Name: LanguageWorkedWith, Length: 64461, dtype: object

# %%
country_grp["LanguageWorkedWith"].apply(lambda x:x.str.contains("Python"))
# Out:
# 0        False
# 1        False
# 2         True
# 3          NaN
# 4        False
#          ...
# 64456      NaN
# 64457     True
# 64458      NaN
# 64459    False
# 64460    False
# Name: LanguageWorkedWith, Length: 64461, dtype: object

# %%
country_grp["LanguageWorkedWith"].apply(lambda x:x.str.contains("Python").sum())
# Out:
# Country
# Afghanistan                              11
# Albania                                  13
# Algeria                                  40
# Andorra                                   3
# Angola                                    1
#                                        ...
# Venezuela, Bolivarian Republic of...     29
# Viet Nam                                102
# Yemen                                     1
# Zambia                                    4
# Zimbabwe                                 13
# Name: LanguageWorkedWith, Length: 183, dtype: int64

# %%
country_grp["LanguageWorkedWith"].apply(lambda x:x.str.contains("Python").sum()).loc["India"]
# Out:
# 2670

# %%
Python_res=country_grp["LanguageWorkedWith"].apply(lambda x:x.str.contains("Python").sum())

# %%
df["Country"].value_counts()
# Out:
# United States     12469
# India              8403
# United Kingdom     3896
# Germany            3890
# Canada             2191
#                   ...
# Lesotho               1
# Kiribati              1
# Nauru                 1
# Grenada               1
# Saint Lucia           1
# Name: Country, Length: 183, dtype: int64

# %%
res=df["Country"].value_counts()

# %%
Python_res/res
# Out:
# Afghanistan                             0.130952
# Albania                                 0.240741
# Algeria                                 0.425532
# Andorra                                 0.230769
# Angola                                  0.111111
#                                           ...
# Venezuela, Bolivarian Republic of...    0.414286
# Viet Nam                                0.280220
# Yemen                                   0.142857
# Zambia                                  0.190476
# Zimbabwe                                0.419355
# Length: 183, dtype: float64

# %%
(Python_res/res).nlargest()
# Out:
# Gabon                                 1.000000
# Micronesia, Federated States of...    1.000000
# Saint Lucia                           1.000000
# Montenegro                            0.692308
# Brunei Darussalam                     0.666667
# dtype: float64

# %%
ctr_knows_python = country_grp['LanguageWorkedWith'].apply(lambda x: x.str.contains('Python', na=False).value_counts
                                                           (normalize=True))
ctr_knows_python.rename({False:'Don\'t know', True:'I know'}, inplace=True)
ctr_knows_python
# Out:
# Country
# Afghanistan  Don't know    0.869048
#              I know        0.130952
# Albania      Don't know    0.759259
#              I know        0.240741
# Algeria      Don't know    0.574468
#                              ...
# Yemen        I know        0.142857
# Zambia       Don't know    0.809524
#              I know        0.190476
# Zimbabwe     Don't know    0.580645
#              I know        0.419355
# Name: LanguageWorkedWith, Length: 344, dtype: float64

# %%
country_grp['LanguageWorkedWith'].apply(lambda x: x.str.contains('Python', na=False).value_counts
                                                           (normalize=True))
# Out:
# Country
# Afghanistan  False    0.869048
#              True     0.130952
# Albania      False    0.759259
#              True     0.240741
# Algeria      False    0.574468
#                         ...
# Yemen        True     0.142857
# Zambia       False    0.809524
#              True     0.190476
# Zimbabwe     False    0.580645
#              True     0.419355
# Name: LanguageWorkedWith, Length: 344, dtype: float64

# %%
type(ctr_knows_python)
# Out:
# pandas.core.series.Series

# %%
python_df=pd.concat([res,Python_res])

# %%
python_df
# Out:
# United States                           12469
# India                                    8403
# United Kingdom                           3896
# Germany                                  3890
# Canada                                   2191
#                                         ...
# Venezuela, Bolivarian Republic of...       29
# Viet Nam                                  102
# Yemen                                       1
# Zambia                                      4
# Zimbabwe                                   13
# Length: 366, dtype: int64

# %%
python_df.loc["India"]
# Out:
# India    8403
# India    2670
# dtype: int64

# %%
python_df=pd.concat([res,Python_res],axis="columns",sort=False)

# %%
python_df
# Out:
#                 Country  LanguageWorkedWith
# United States     12469                5964
# India              8403                2670
# United Kingdom     3896                1621
# Germany            3890                1712
# Canada             2191                1011
# ...                 ...                 ...
# Lesotho               1                   0
# Kiribati              1                   0
# Nauru                 1                   0
# Grenada               1                   0
# Saint Lucia           1                   1
#
# [183 rows x 2 columns]

# %%
python_df.rename(columns={"Country":"Responder","LanguageWorkedWith":"Python_know"},inplace=True)

# %%
python_df
# Out:
#                 Responder  Python_know
# United States       12469         5964
# India                8403         2670
# United Kingdom       3896         1621
# Germany              3890         1712
# Canada               2191         1011
# ...                   ...          ...
# Lesotho                 1            0
# Kiribati                1            0
# Nauru                   1            0
# Grenada                 1            0
# Saint Lucia             1            1
#
# [183 rows x 2 columns]

# %%
python_df["pctknows_python"]=1/(python_df["Responder"]/python_df["Python_know"])*100

# %%
python_df
# Out:
#                 Responder  Python_know  pctknows_python
# United States       12469         5964        47.830620
# India                8403         2670        31.774366
# United Kingdom       3896         1621        41.606776
# Germany              3890         1712        44.010283
# Canada               2191         1011        46.143314
# ...                   ...          ...              ...
# Lesotho                 1            0         0.000000
# Kiribati                1            0         0.000000
# Nauru                   1            0         0.000000
# Grenada                 1            0         0.000000
# Saint Lucia             1            1       100.000000
#
# [183 rows x 3 columns]

# %%
python_df.sort_values(by="pctknows_python",ascending=False)
# Out:
#                                     Responder  Python_know  pctknows_python
# Saint Lucia                                 1            1       100.000000
# Gabon                                       1            1       100.000000
# Micronesia, Federated States of...          1            1       100.000000
# Montenegro                                 13            9        69.230769
# Brunei Darussalam                           3            2        66.666667
# ...                                       ...          ...              ...
# Burundi                                     2            0         0.000000
# Cape Verde                                  2            0         0.000000
# Monaco                                      2            0         0.000000
# Saint Vincent and the Grenadines            3            0         0.000000
# Antigua and Barbuda                         2            0         0.000000
#
# [183 rows x 3 columns]

# %%
python_df.loc["India"]
# Out:
# Responder          8403.000000
# Python_know        2670.000000
# pctknows_python      31.774366
# Name: India, dtype: float64
