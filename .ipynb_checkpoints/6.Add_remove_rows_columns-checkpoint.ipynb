# %%
import pandas as pd
import math

# %%
df=pd.read_csv("survey_results_public.csv")

# %%
df_schema=pd.read_csv("survey_results_schema.csv")

# %%
df
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1                     I am a developer by profession      Yes
# 1               2                     I am a developer by profession       No
# 2               3                        I code primarily as a hobby      Yes
# 3               4                     I am a developer by profession      Yes
# 4               5  I used to be a developer by profession, but no...      Yes
# ...           ...                                                ...      ...
# 64456       64858                                                NaN      Yes
# 64457       64867                                                NaN      Yes
# 64458       64898                                                NaN      Yes
# 64459       64925                                                NaN      Yes
# 64460       65112                                                NaN      Yes
#
# ...

# %%
df_schema
# Out:
#                 Column                                       QuestionText
# 0           Respondent  Randomized respondent ID number (not in order ...
# 1           MainBranch  Which of the following options best describes ...
# 2             Hobbyist                            Do you code as a hobby?
# 3                  Age  What is your age (in years)? If you prefer not...
# 4           Age1stCode  At what age did you write your first line of c...
# ..                 ...                                                ...
# 56  WebframeWorkedWith  Which web frameworks have you done extensive d...
# 57       WelcomeChange  Compared to last year, how welcome do you feel...
# 58         WorkWeekHrs  On average, how many hours per week do you wor...
# 59           YearsCode  Including any education, how many years have y...
# 60        YearsCodePro  NOT including education, how many years have y...
#
# [61 rows x 2 columns]

# %%
people={"first":["Rajat","corey","John"],
        "last":["Gupta","sch","doe"],
        "email":["RajatGupta@email.com","corey@email.com","john@email.com"]}

# %%
df2=pd.DataFrame(people)

# %%
df2
# Out:
#    first   last                 email
# 0  Rajat  Gupta  RajatGupta@email.com
# 1  corey    sch       corey@email.com
# 2   John    doe        john@email.com

# %%
df2["length"]=df2["first"].apply(len)

# %%
df2
# Out:
#    first   last                 email  length
# 0  Rajat  Gupta  RajatGupta@email.com       5
# 1  corey    sch       corey@email.com       5
# 2   John    doe        john@email.com       4

# %%
df2["new_email"]=df2["first"]+"@mail.com"

# %%
df2
# Out:
#    first   last                 email  length       new_email
# 0  Rajat  Gupta  RajatGupta@email.com       5  Rajat@mail.com
# 1  corey    sch       corey@email.com       5  corey@mail.com
# 2   John    doe        john@email.com       4   John@mail.com

# %%
df2["new_email"].str.split("@")
# Out:
# 0    [Rajat, mail.com]
# 1    [corey, mail.com]
# 2     [John, mail.com]
# Name: new_email, dtype: object

# %%
df2.drop(columns=["length","new_email"],inplace=True)

# %%
df2
# Out:
#    first   last                 email
# 0  Rajat  Gupta  RajatGupta@email.com
# 1  corey    sch       corey@email.com
# 2   John    doe        john@email.com

# %%
df2["full"]=df2["first"]+" "+df2["last"]

# %%
df2
# Out:
#    first   last                 email         full
# 0  Rajat  Gupta  RajatGupta@email.com  Rajat Gupta
# 1  corey    sch       corey@email.com    corey sch
# 2   John    doe        john@email.com     John doe

# %%
df2["full"].str.split(" ")
# Out:
# 0    [Rajat, Gupta]
# 1      [corey, sch]
# 2       [John, doe]
# Name: full, dtype: object

# %%
df2["full"].str.split(" ",expand=True)
# Out:
#        0      1
# 0  Rajat  Gupta
# 1  corey    sch
# 2   John    doe

# %%
df2[["first_name","last_name"]]=df2["full"].str.split(" ",expand=True)

# %%
df2
# Out:
#    first   last                 email         full first_name last_name
# 0  Rajat  Gupta  RajatGupta@email.com  Rajat Gupta      Rajat     Gupta
# 1  corey    sch       corey@email.com    corey sch      corey       sch
# 2   John    doe        john@email.com     John doe       John       doe

# %%
df2.append({"first":"xxx"},ignore_index=True)
# Out:
#    first   last                 email         full first_name last_name
# 0  Rajat  Gupta  RajatGupta@email.com  Rajat Gupta      Rajat     Gupta
# 1  corey    sch       corey@email.com    corey sch      corey       sch
# 2   John    doe        john@email.com     John doe       John       doe
# 3    xxx    NaN                   NaN          NaN        NaN       NaN

# %%
df2=df2.append({"first":"xxx"},ignore_index=True)

# %%
df2
# Out:
#    first   last                 email         full first_name last_name
# 0  Rajat  Gupta  RajatGupta@email.com  Rajat Gupta      Rajat     Gupta
# 1  corey    sch       corey@email.com    corey sch      corey       sch
# 2   John    doe        john@email.com     John doe       John       doe
# 3    xxx    NaN                   NaN          NaN        NaN       NaN

# %%
df2=df2.append(pd.Series({"first":"xxx"},name=100))

# %%
df2
# Out:
#      first   last                 email         full first_name last_name
# 0    Rajat  Gupta  RajatGupta@email.com  Rajat Gupta      Rajat     Gupta
# 1    corey    sch       corey@email.com    corey sch      corey       sch
# 2     John    doe        john@email.com     John doe       John       doe
# 3      xxx    NaN                   NaN          NaN        NaN       NaN
# 100    xxx    NaN                   NaN          NaN        NaN       NaN

# %%
people={"first2":["Rajat","corey","John"],
        "last2":["Gupta","sch","doe"],
        "email2":["RajatGupta@email.com","corey@email.com","john@email.com"]}

# %%
df3=pd.DataFrame(people)

# %%
df3
# Out:
#   first2  last2                email2
# 0  Rajat  Gupta  RajatGupta@email.com
# 1  corey    sch       corey@email.com
# 2   John    doe        john@email.com

# %%
df2.append(df3,ignore_index=True)
# Out:
#    first   last                 email         full first_name last_name  \
# 0  Rajat  Gupta  RajatGupta@email.com  Rajat Gupta      Rajat     Gupta
# 1  corey    sch       corey@email.com    corey sch      corey       sch
# 2   John    doe        john@email.com     John doe       John       doe
# 3    xxx    NaN                   NaN          NaN        NaN       NaN
# 4    xxx    NaN                   NaN          NaN        NaN       NaN
# 5    NaN    NaN                   NaN          NaN        NaN       NaN
# 6    NaN    NaN                   NaN          NaN        NaN       NaN
# 7    NaN    NaN                   NaN          NaN        NaN       NaN
#
#   first2  last2                email2
# 0    NaN    NaN                   NaN
# 1    NaN    NaN                   NaN
# 2    NaN    NaN                   NaN
# 3    NaN    NaN                   NaN
# 4    NaN    NaN                   NaN
# 5  Rajat  Gupta  RajatGupta@email.com
# 6  corey    sch       corey@email.com
# ...

# %%
df3=pd.DataFrame(people,index=[20,30,40])
df3
# Out:
#    first2  last2                email2
# 20  Rajat  Gupta  RajatGupta@email.com
# 30  corey    sch       corey@email.com
# 40   John    doe        john@email.com

# %%
df2.append(df3)
# Out:
#      first   last                 email         full first_name last_name  \
# 0    Rajat  Gupta  RajatGupta@email.com  Rajat Gupta      Rajat     Gupta
# 1    corey    sch       corey@email.com    corey sch      corey       sch
# 2     John    doe        john@email.com     John doe       John       doe
# 3      xxx    NaN                   NaN          NaN        NaN       NaN
# 100    xxx    NaN                   NaN          NaN        NaN       NaN
# 20     NaN    NaN                   NaN          NaN        NaN       NaN
# 30     NaN    NaN                   NaN          NaN        NaN       NaN
# 40     NaN    NaN                   NaN          NaN        NaN       NaN
#
#     first2  last2                email2
# 0      NaN    NaN                   NaN
# 1      NaN    NaN                   NaN
# 2      NaN    NaN                   NaN
# 3      NaN    NaN                   NaN
# 100    NaN    NaN                   NaN
# 20   Rajat  Gupta  RajatGupta@email.com
# ...

# %%
df2
# Out:
#      first   last                 email         full first_name last_name
# 0    Rajat  Gupta  RajatGupta@email.com  Rajat Gupta      Rajat     Gupta
# 1    corey    sch       corey@email.com    corey sch      corey       sch
# 2     John    doe        john@email.com     John doe       John       doe
# 3      xxx    NaN                   NaN          NaN        NaN       NaN
# 100    xxx    NaN                   NaN          NaN        NaN       NaN

# %%
df2=df2.drop(columns=["first_name","last_name","first"])

# %%
df2=df2.drop(index=100)

# %%
df2.drop(index=3,inplace=True)

# %%
df2
# Out:
#     last                 email         full
# 0  Gupta  RajatGupta@email.com  Rajat Gupta
# 1    sch       corey@email.com    corey sch
# 2    doe        john@email.com     John doe

# %%
df2.drop(columns="last")
# Out:
#                   email         full
# 0  RajatGupta@email.com  Rajat Gupta
# 1       corey@email.com    corey sch
# 2        john@email.com     John doe

# %%
df2.drop(index=[1,2])
# Out:
#     last                 email         full
# 0  Gupta  RajatGupta@email.com  Rajat Gupta

# %%
df2.drop(index=df2[df2["last"]=='doe'].index)
# Out:
#     last                 email         full
# 0  Gupta  RajatGupta@email.com  Rajat Gupta
# 1    sch       corey@email.com    corey sch
