# %%
import pandas as pd
import math
df=pd.read_csv("survey_results_public.csv")
df_schema=pd.read_csv("survey_results_schema.csv")
people={"first":["Rajat","Corey","John"],
        "last":["Gupta","Sch","Doe"],
        "email":["RajatGupta@email.com","corey@email.com","john@email.com"]}
df2=pd.DataFrame(people)

# %%
df
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1                     I am a developer by profession      Yes
# 1               2                     I am a developer by profession       No
# 2               3                        I code primarily as a hobby      Yes
# 3               4                     I am a developer by profession      Yes
# 4               5  I used to be a developer by profession, but no...      Yes
# ...           ...                                                ...      ...
# 64456       64858                                                NaN      Yes
# 64457       64867                                                NaN      Yes
# 64458       64898                                                NaN      Yes
# 64459       64925                                                NaN      Yes
# 64460       65112                                                NaN      Yes
#
# ...

# %%
df_schema
# Out:
#                 Column                                       QuestionText
# 0           Respondent  Randomized respondent ID number (not in order ...
# 1           MainBranch  Which of the following options best describes ...
# 2             Hobbyist                            Do you code as a hobby?
# 3                  Age  What is your age (in years)? If you prefer not...
# 4           Age1stCode  At what age did you write your first line of c...
# ..                 ...                                                ...
# 56  WebframeWorkedWith  Which web frameworks have you done extensive d...
# 57       WelcomeChange  Compared to last year, how welcome do you feel...
# 58         WorkWeekHrs  On average, how many hours per week do you wor...
# 59           YearsCode  Including any education, how many years have y...
# 60        YearsCodePro  NOT including education, how many years have y...
#
# [61 rows x 2 columns]

# %%
df2
# Out:
#    first   last                 email
# 0  Rajat  Gupta  RajatGupta@email.com
# 1  Corey    Sch       corey@email.com
# 2   John    Doe        john@email.com

# %%
df2.sort_values(by="last")
# Out:
#    first   last                 email
# 2   John    Doe        john@email.com
# 0  Rajat  Gupta  RajatGupta@email.com
# 1  Corey    Sch       corey@email.com

# %%
df2
# Out:
#    first   last                 email
# 0  Rajat  Gupta  RajatGupta@email.com
# 1  Corey    Sch       corey@email.com
# 2   John    Doe        john@email.com

# %%
df2.sort_values(by="last",inplace=True)

# %%
df2
# Out:
#    first   last                 email
# 2   John    Doe        john@email.com
# 0  Rajat  Gupta  RajatGupta@email.com
# 1  Corey    Sch       corey@email.com

# %%
df2.sort_values(by="last",ascending=False)
# Out:
#    first   last                 email
# 1  Corey    Sch       corey@email.com
# 0  Rajat  Gupta  RajatGupta@email.com
# 2   John    Doe        john@email.com

# %%
df2.sort_values(by=["first","last"],ascending=[True,False])
# Out:
#    first   last                 email
# 1  Corey    Sch       corey@email.com
# 2   John    Doe        john@email.com
# 0  Rajat  Gupta  RajatGupta@email.com

# %%
df2
# Out:
#    first   last                 email
# 2   John    Doe        john@email.com
# 0  Rajat  Gupta  RajatGupta@email.com
# 1  Corey    Sch       corey@email.com

# %%
df2.drop(columns="last")
# Out:
#    first                 email
# 2   John        john@email.com
# 0  Rajat  RajatGupta@email.com
# 1  Corey       corey@email.com

# %%
df2.drop(columns="last",inplace=True)

# %%
df2.sort_index(inplace=True)

# %%
df2["last"]=["Gupta","Sch","doe"]

# %%
df2
# Out:
#    first                 email   last
# 0  Rajat  RajatGupta@email.com  Gupta
# 1  Corey       corey@email.com    Sch
# 2   John        john@email.com    doe

# %%
df2.loc[1,"last"]="doe"

# %%
df2
# Out:
#    first                 email   last
# 0  Rajat  RajatGupta@email.com  Gupta
# 1  Corey       corey@email.com    doe
# 2   John        john@email.com    doe

# %%
df2.sort_values(by=["last","first"],ascending=[True,False])
# Out:
#    first                 email   last
# 0  Rajat  RajatGupta@email.com  Gupta
# 2   John        john@email.com    doe
# 1  Corey       corey@email.com    doe

# %%
df2.sort_values(by=0,axis=1)
# Out:
#     last  first                 email
# 0  Gupta  Rajat  RajatGupta@email.com
# 1    doe  Corey       corey@email.com
# 2    doe   John        john@email.com

# %%
df2.sort_values(by=[0],axis=1,inplace=True)

# %%
df2
# Out:
#     last  first                 email
# 0  Gupta  Rajat  RajatGupta@email.com
# 1    doe  Corey       corey@email.com
# 2    doe   John        john@email.com

# %%
df2.sort_index()
# Out:
#     last  first                 email
# 0  Gupta  Rajat  RajatGupta@email.com
# 1    doe  Corey       corey@email.com
# 2    doe   John        john@email.com

# %%
df2["last"].sort_values()
# Out:
# 0    Gupta
# 1      doe
# 2      doe
# Name: last, dtype: object

# %%
df
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1                     I am a developer by profession      Yes
# 1               2                     I am a developer by profession       No
# 2               3                        I code primarily as a hobby      Yes
# 3               4                     I am a developer by profession      Yes
# 4               5  I used to be a developer by profession, but no...      Yes
# ...           ...                                                ...      ...
# 64456       64858                                                NaN      Yes
# 64457       64867                                                NaN      Yes
# 64458       64898                                                NaN      Yes
# 64459       64925                                                NaN      Yes
# 64460       65112                                                NaN      Yes
#
# ...

# %%
df.loc[:,"Hobbyist":"Country"].nlargest(10,"ConvertedComp")
# Out:
#      Hobbyist   Age Age1stCode CompFreq  CompTotal  ConvertedComp  \
# 121       Yes  26.0         12   Weekly   120000.0      2000000.0
# 123       Yes  41.0         30  Monthly   200000.0      2000000.0
# 191       Yes  29.0         16   Weekly   120000.0      2000000.0
# 663       Yes  24.0         13   Weekly   150000.0      2000000.0
# 697       Yes  39.0         16   Weekly    52000.0      2000000.0
# 722       Yes   NaN         12   Weekly   103000.0      2000000.0
# 816       Yes  40.0         15   Weekly    70000.0      2000000.0
# 982       Yes  27.0         11   Weekly    81000.0      2000000.0
# 1018      Yes  34.0         16   Weekly   142000.0      2000000.0
# 1032      Yes  26.0         11   Weekly    68500.0      2000000.0
#
#             Country
# 121   United States
# 123   United States
# 191   United States
# 663   United States
# 697   United States
# 722   United States
# 816   United States
# 982   United States
# 1018  United States
# 1032  United States

# %%
df.nlargest(10,"ConvertedComp")
# Out:
#       Respondent                                         MainBranch Hobbyist  \
# 121          123                     I am a developer by profession      Yes
# 123          125  I am not primarily a developer, but I write co...      Yes
# 191          193                     I am a developer by profession      Yes
# 663          665                     I am a developer by profession      Yes
# 697          699  I am not primarily a developer, but I write co...      Yes
# 722          724  I am not primarily a developer, but I write co...      Yes
# 816          818  I am not primarily a developer, but I write co...      Yes
# 982          986                     I am a developer by profession      Yes
# 1018        1022                     I am a developer by profession      Yes
# 1032        1036                     I am a developer by profession      Yes
#
#        Age Age1stCode CompFreq  CompTotal  ConvertedComp        Country  \
# ...

# %%
df["Hobbyist":"Country"].nlargest(10,"ConvertedComp")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-28-2606557c4932> in <module>
# ----> 1 df["Hobbyist":"Country"].nlargest(10,"ConvertedComp")
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2879
#    2880         # Do we have a slicer (on rows)?
# -> 2881         indexer = convert_to_index_sliceable(self, key)
#    2882         if indexer is not None:
#    2883             # either we have a slice or we have a string that can be converted
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in convert_to_index_sliceable(obj, key)
#    2132     idx = obj.index
#    2133     if isinstance(key, slice):
# -> 2134         return idx._convert_slice_indexer(key, kind="getitem")
#    2135
#    2136     elif isinstance(key, str):
#
# ...

# %%
df.loc[:,"Hobbyist":"Country"].nlargest(10,"Hobbyist")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-29-b3697407266c> in <module>
# ----> 1 df.loc[:,"Hobbyist":"Country"].nlargest(10,"Hobbyist")
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in nlargest(self, n, columns, keep)
#    5679         Brunei      434000    12128      BN
#    5680         """
# -> 5681         return algorithms.SelectNFrame(self, n=n, keep=keep, columns=columns).nlargest()
#    5682
#    5683     def nsmallest(self, n, columns, keep="first") -> "DataFrame":
#
# ~\anaconda3\lib\site-packages\pandas\core\algorithms.py in nlargest(self)
#    1132
#    1133     def nlargest(self):
# -> 1134         return self.compute("nlargest")
#    1135
#    1136     def nsmallest(self):
#
# ~\anaconda3\lib\site-packages\pandas\core\algorithms.py in compute(self, method)
#    1248             dtype = frame[column].dtype
# ...

# %%
df.loc[:,"Hobbyist":"Country"].nsmallest(10,"ConvertedComp")
# Out:
#      Hobbyist   Age Age1stCode CompFreq  CompTotal  ConvertedComp  \
# 122        No  38.0         14   Yearly        0.0            0.0
# 236       Yes   NaN         13   Yearly        0.0            0.0
# 882       Yes  41.0         10   Yearly        0.0            0.0
# 1112      Yes  25.0         11   Yearly        0.0            0.0
# 1272      Yes  21.0         12   Yearly        0.0            0.0
# 1785      Yes   NaN          8   Yearly        0.0            0.0
# 2064      Yes  27.0         18   Yearly        0.0            0.0
# 2187      Yes   NaN         24  Monthly        1.0            0.0
# 2239       No   NaN         12   Yearly        0.0            0.0
# 2314      Yes   NaN         15   Yearly        0.0            0.0
#
#                   Country
# 122         United States
# 236         United States
# 882         United States
# 1112        United States
# 1272       United Kingdom
# 1785        United States
# 2064               Canada
# ...

# %%
df2
# Out:
#     last  first                 email
# 0  Gupta  Rajat  RajatGupta@email.com
# 1    doe  Corey       corey@email.com
# 2    doe   John        john@email.com

# %%
df2.sort_values(by=2,axis=1,ascending=False)
# Out:
#                   email   last  first
# 0  RajatGupta@email.com  Gupta  Rajat
# 1       corey@email.com    doe  Corey
# 2        john@email.com    doe   John
