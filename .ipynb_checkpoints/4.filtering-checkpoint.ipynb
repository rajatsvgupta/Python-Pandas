# %%
people={"first":["Rajat","corey","John"],
        "last":["Gupta","sch","doe"],
        "email":["RajatGupta@email.com","corey@email.com","john@email.com"]}
import pandas as pd
df=pd.read_csv("survey_results_public.csv")
df2=pd.DataFrame(people)
schema_df=pd.read_csv("survey_results_schema.csv")

# %%
df2
# Out:
#    first   last                 email
# 0  Rajat  Gupta  RajatGupta@email.com
# 1  corey    sch       corey@email.com
# 2   John    doe        john@email.com

# %%
df2["last"]=="Gupta"
# Out:
# 0     True
# 1    False
# 2    False
# Name: last, dtype: bool

# %%
df2.replace("sch","doe",inplace=True)

# %%
df2
# Out:
#    first   last                 email
# 0  Rajat  Gupta  RajatGupta@email.com
# 1  corey    doe       corey@email.com
# 2   John    doe        john@email.com

# %%
filt=(df2["last"]=="doe")

# %%
df2[filt]
# Out:
#    first last            email
# 1  corey  doe  corey@email.com
# 2   John  doe   john@email.com

# %%
df2.loc[filt]
# Out:
#    first last            email
# 1  corey  doe  corey@email.com
# 2   John  doe   john@email.com

# %%
df2[filt]["email"]
# Out:
# 1    corey@email.com
# 2     john@email.com
# Name: email, dtype: object

# %%
df2.loc[filt,"email"]
# Out:
# 1    corey@email.com
# 2     john@email.com
# Name: email, dtype: object

# %%
filt=(df2["first"]=="Rajat") & (df2["last"]=="Gupta")

# %%
df2
# Out:
#    first   last                 email
# 0  Rajat  Gupta  RajatGupta@email.com
# 1  corey    doe       corey@email.com
# 2   John    doe        john@email.com

# %%
df2[filt]
# Out:
#    first   last                 email
# 0  Rajat  Gupta  RajatGupta@email.com

# %%
filt=(df2["first"]=="Rajat") | (df2["last"]=="doe")

# %%
df2[filt]
# Out:
#    first   last                 email
# 0  Rajat  Gupta  RajatGupta@email.com
# 1  corey    doe       corey@email.com
# 2   John    doe        john@email.com

# %%
filt= (df2["last"]=="doe")

# %%
df2[~filt]
# Out:
#    first   last                 email
# 0  Rajat  Gupta  RajatGupta@email.com

# %%
high_salary=(df["ConvertedComp"]>70000)

# %%
high_salary
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 64456    False
# 64457    False
# 64458    False
# 64459    False
# 64460    False
# Name: ConvertedComp, Length: 64461, dtype: bool

# %%
pd.set_option("display.max_row",61)
schema_df
# Out:
#                           Column  \
# 0                     Respondent
# 1                     MainBranch
# 2                       Hobbyist
# 3                            Age
# 4                     Age1stCode
# 5                       CompFreq
# 6                      CompTotal
# 7                  ConvertedComp
# 8                        Country
# 9                   CurrencyDesc
# 10                CurrencySymbol
# 11        DatabaseDesireNextYear
# 12            DatabaseWorkedWith
# 13                       DevType
# 14                       EdLevel
# 15                    Employment
# 16                     Ethnicity
# 17                        Gender
# 18                    JobFactors
# 19                        JobSat
# 20                       JobSeek
# 21        LanguageDesireNextYear
# 22            LanguageWorkedWith
# 23        MiscTechDesireNextYear
# 24            MiscTechWorkedWith
# 25  NEWCollabToolsDesireNextYear
# 26      NEWCollabToolsWorkedWith
# ...

# %%
high_salary
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 64456    False
# 64457    False
# 64458    False
# 64459    False
# 64460    False
# Name: ConvertedComp, Length: 64461, dtype: bool

# %%
high_salary.head(50)
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7      True
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15     True
# 16     True
# 17     True
# 18     True
# 19    False
# 20    False
# 21    False
# 22    False
# 23     True
# 24    False
# 25     True
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35     True
# 36    False
# 37     True
# 38    False
# 39    False
# 40     True
# 41     True
# 42     True
# 43    False
# 44    False
# 45    False
# 46     True
# 47     True
# 48    False
# 49    False
# Name: ConvertedComp, dtype: bool

# %%
df.loc[high_salary,["ConvertedComp","Country","Age","LanguageWorkedWith"]]
# Out:
#        ConvertedComp         Country   Age  \
# 7           116000.0   United States  36.0
# 15          108576.0  United Kingdom  45.0
# 16           79000.0   United States  25.0
# 17         1260000.0   United States  32.0
# 18           83400.0   United States  24.0
# ...              ...             ...   ...
# 64113       225000.0   United States   NaN
# 64116       150000.0   United States   NaN
# 64127       140000.0   United States   NaN
# 64129       150000.0   United States   NaN
# 64141       129718.0         Germany   NaN
#
#                                       LanguageWorkedWith
# 7                                             Python;SQL
# 15     Bash/Shell/PowerShell;HTML/CSS;Java;JavaScript...
# 16                 C#;HTML/CSS;JavaScript;Python;SQL;VBA
# 17                   Bash/Shell/PowerShell;HTML/CSS;Perl
# 18     Bash/Shell/PowerShell;C#;HTML/CSS;JavaScript;S...
# ...                                                  ...
# ...

# %%
df.loc[high_salary,["ConvertedComp","Country","Age","LanguageWorkedWith"]].head(50)
# Out:
#      ConvertedComp         Country   Age  \
# 7         116000.0   United States  36.0
# 15        108576.0  United Kingdom  45.0
# 16         79000.0   United States  25.0
# 17       1260000.0   United States  32.0
# 18         83400.0   United States  24.0
# 23         91883.0         Germany  45.0
# 25         71093.0          Canada   NaN
# 35         77556.0  United Kingdom  34.0
# 37         97288.0           Italy  35.0
# 40        106000.0   United States   NaN
# 41        130000.0   United States  32.0
# 42        135000.0   United States   NaN
# 46         74970.0  United Kingdom  53.0
# 47        125000.0   United States  38.0
# 50        103615.0          Canada   NaN
# 51         90482.0  United Kingdom  28.0
# 53        160000.0   United States  44.0
# 56       1620000.0   United States  44.0
# 63         94359.0  United Kingdom  34.0
# 64       1176000.0   United States  34.0
# 66        250000.0   United States  35.0
# 68        594539.0          France  25.0
# ...

# %%
countries=["United States","India","Canada"]

# %%
filt=df["Country"].isin(countries)

# %%
filt
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4         True
#          ...
# 64456     True
# 64457    False
# 64458    False
# 64459    False
# 64460    False
# Name: Country, Length: 64461, dtype: bool

# %%
df.loc[filt]
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 4               5  I used to be a developer by profession, but no...      Yes
# 6               7                     I am a developer by profession      Yes
# 7               8                     I am a developer by profession      Yes
# 13             14                     I am a developer by profession      Yes
# 16             17                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 64441       62834                                                NaN      Yes
# 64442       62954                                                NaN      Yes
# 64443       63077                                                NaN      Yes
# 64452       64236                                                NaN      Yes
# 64456       64858                                                NaN      Yes
#
# ...

# %%
df["LanguageWorkedWith"].str.contains("Python")
# Out:
# 0        False
# 1        False
# 2         True
# 3          NaN
# 4        False
#          ...
# 64456      NaN
# 64457     True
# 64458      NaN
# 64459    False
# 64460    False
# Name: LanguageWorkedWith, Length: 64461, dtype: object

# %%
filt=(df["ConvertedComp"]>700000) & (df["LanguageWorkedWith"].str.contains("Python")) & (df["Country"].isin(countries))

# %%
df.loc[filt,["ConvertedComp","LanguageWorkedWith","Country","Age"]]
# Out:
#        ConvertedComp                                 LanguageWorkedWith  \
# 121        2000000.0           Bash/Shell/PowerShell;C++;Go;Java;Python
# 123        2000000.0                                         Python;SQL
# 663        2000000.0                    HTML/CSS;JavaScript;Python;Ruby
# 816        2000000.0  Bash/Shell/PowerShell;HTML/CSS;Java;Python;SQL...
# 931        1000000.0                         HTML/CSS;JavaScript;Python
# ...              ...                                                ...
# 61350      1560000.0  Bash/Shell/PowerShell;C;C#;C++;Go;HTML/CSS;Jav...
# 61373      1560000.0                              C;C++;Python;Rust;SQL
# 63890      2000000.0  Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...
# 64035      2000000.0  C#;HTML/CSS;JavaScript;Perl;Python;SQL;TypeScript
# 64057      2000000.0  Bash/Shell/PowerShell;HTML/CSS;Java;JavaScript...
#
#              Country   Age
# 121    United States  26.0
# 123    United States  41.0
# ...

# %%
df.loc[filt,["ConvertedComp","LanguageWorkedWith","Country","Age"]]["Country"].value_counts()
# Out:
# United States    200
# Canada            24
# India              5
# Name: Country, dtype: int64

# %%
filt=(df["ConvertedComp"]>700000)

# %%
df[filt]["Country"].value_counts()
# Out:
# United States                       441
# United Kingdom                      127
# Germany                              58
# Canada                               56
# Australia                            53
# Ireland                              25
# Norway                               17
# Switzerland                          17
# New Zealand                          15
# India                                12
# Japan                                 9
# France                                9
# Netherlands                           9
# Italy                                 9
# Spain                                 7
# Austria                               7
# Singapore                             4
# Denmark                               4
# Israel                                4
# Portugal                              4
# Belgium                               4
# Sweden                                3
# Poland                                3
# ...

# %%
df2.loc[2,["first","email"]]=["john","john@email.com"]

# %%
df2
# Out:
#    first   last                 email
# 0  Rajat  Gupta  RajatGupta@email.com
# 1  corey    doe       corey@email.com
# 2   john    doe        john@email.com

# %%
df2["last"][[1,2]]
# Out:
# 1    doe
# 2    doe
# Name: last, dtype: object

# %%
df.loc[filt,"LanguageWorkedWith"].str.contains("Python")
# Out:
# 17       False
# 56       False
# 64       False
# 121       True
# 123       True
#          ...
# 63890     True
# 63925      NaN
# 63993      NaN
# 64035     True
# 64057     True
# Name: LanguageWorkedWith, Length: 939, dtype: object

# %%
df["LanguageWorkedWith"].str.contains("Python")
# Out:
# 0        False
# 1        False
# 2         True
# 3          NaN
# 4        False
#          ...
# 64456      NaN
# 64457     True
# 64458      NaN
# 64459    False
# 64460    False
# Name: LanguageWorkedWith, Length: 64461, dtype: object

# %%
filt=df["LanguageWorkedWith"].str.contains("Python")

# %%
df[filt]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-41-fe2f66bc4df2> in <module>
# ----> 1 df[filt]
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2890
#    2891         # Do we have a (boolean) 1d indexer?
# -> 2892         if com.is_bool_indexer(key):
#    2893             return self._getitem_bool_array(key)
#    2894
#
# ~\anaconda3\lib\site-packages\pandas\core\common.py in is_bool_indexer(key)
#     132                 na_msg = "Cannot mask with non-boolean array containing NA / NaN values"
#     133                 if isna(key).any():
# --> 134                     raise ValueError(na_msg)
#     135                 return False
#     136             return True
#
# ValueError: Cannot mask with non-boolean array containing NA / NaN values

# %%
df["LanguageWorkedWith"].str.contains("Python",na=False)
# Out:
# 0        False
# 1        False
# 2         True
# 3        False
# 4        False
#          ...
# 64456    False
# 64457     True
# 64458    False
# 64459    False
# 64460    False
# Name: LanguageWorkedWith, Length: 64461, dtype: bool

# %%
filt=df["LanguageWorkedWith"].str.contains("Python",na=False)

# %%
df[filt]
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 2               3                        I code primarily as a hobby      Yes
# 7               8                     I am a developer by profession      Yes
# 9              10                     I am a developer by profession      Yes
# 12             13  I am not primarily a developer, but I write co...      Yes
# 14             15             I am a student who is learning to code      Yes
# ...           ...                                                ...      ...
# 64433       61561                                                NaN      Yes
# 64438       62391                                                NaN      Yes
# 64443       63077                                                NaN      Yes
# 64446       63640                                                NaN      Yes
# 64457       64867                                                NaN      Yes
#
# ...
