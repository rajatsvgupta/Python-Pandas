# %%
import pandas as pd
import math
import numpy as np
df=pd.read_csv("ETH_1h.csv")

# %%
df
# Out:
#                    Date  Symbol    Open    High     Low   Close      Volume
# 0      2020-03-13 08-PM  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1      2020-03-13 07-PM  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2      2020-03-13 06-PM  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3      2020-03-13 05-PM  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4      2020-03-13 04-PM  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ...                 ...     ...     ...     ...     ...     ...         ...
# 23669  2017-07-01 03-PM  ETHUSD  265.74  272.74  265.00  272.57  1500282.55
# 23670  2017-07-01 02-PM  ETHUSD  268.79  269.90  265.00  265.74  1702536.85
# 23671  2017-07-01 01-PM  ETHUSD  274.83  274.93  265.00  268.79  3010787.99
# 23672  2017-07-01 12-PM  ETHUSD  275.01  275.01  271.00  274.83   824362.87
# 23673  2017-07-01 11-AM  ETHUSD  279.98  279.99  272.10  275.01   679358.87
#
# [23674 rows x 7 columns]

# %%
df.loc[0,"Date"]
# Out:
# '2020-03-13 08-PM'

# %%
df.loc[0,"Date"].day_name()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-f3e2265811cf> in <module>
# ----> 1 df.loc[0,"Date"].day_name()
#
# AttributeError: 'str' object has no attribute 'day_name'

# %%
pd.to_datetime(df["Date"])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\arrays\datetimes.py in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object)
#    2053         try:
# -> 2054             values, tz_parsed = conversion.datetime_to_datetime64(data)
#    2055             # If tzaware, these values represent unix timestamps, so we
#
# pandas\_libs\tslibs\conversion.pyx in pandas._libs.tslibs.conversion.datetime_to_datetime64()
#
# TypeError: Unrecognized value type: <class 'str'>
#
# During handling of the above exception, another exception occurred:
#
# ParserError                               Traceback (most recent call last)
# <ipython-input-5-a389c144bbd3> in <module>
# ----> 1 pd.to_datetime(df["Date"])
#
# ...

# %%
pd.to_datetime(df["Date"],format="%Y-%m-%d %I-%p")

# %%
df["Date"]=pd.to_datetime(df["Date"],format="%Y-%m-%d %I-%p")

# %%
df
# Out:
#                      Date  Symbol    Open    High     Low   Close      Volume
# 0     2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1     2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2     2020-03-13 18:00:00  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3     2020-03-13 17:00:00  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4     2020-03-13 16:00:00  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ...                   ...     ...     ...     ...     ...     ...         ...
# 23669 2017-07-01 15:00:00  ETHUSD  265.74  272.74  265.00  272.57  1500282.55
# 23670 2017-07-01 14:00:00  ETHUSD  268.79  269.90  265.00  265.74  1702536.85
# 23671 2017-07-01 13:00:00  ETHUSD  274.83  274.93  265.00  268.79  3010787.99
# 23672 2017-07-01 12:00:00  ETHUSD  275.01  275.01  271.00  274.83   824362.87
# 23673 2017-07-01 11:00:00  ETHUSD  279.98  279.99  272.10  275.01   679358.87
#
# [23674 rows x 7 columns]

# %%
df.loc[0,"Date"].day_name()
# Out:
# 'Friday'

# %%
df.loc[0,"Date"].day_name()
# Out:
# 'Friday'

# %%
import datetime
d_parse=lambda x:datetime.datetime.strptime(x,"%Y-%m-%d %I-%p")

# %%
df=pd.read_csv("ETH_1h.csv",parse_dates=["Date"],date_parser=d_parse)

# %%
df
# Out:
#                      Date  Symbol    Open    High     Low   Close      Volume
# 0     2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1     2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2     2020-03-13 18:00:00  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3     2020-03-13 17:00:00  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4     2020-03-13 16:00:00  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ...                   ...     ...     ...     ...     ...     ...         ...
# 23669 2017-07-01 15:00:00  ETHUSD  265.74  272.74  265.00  272.57  1500282.55
# 23670 2017-07-01 14:00:00  ETHUSD  268.79  269.90  265.00  265.74  1702536.85
# 23671 2017-07-01 13:00:00  ETHUSD  274.83  274.93  265.00  268.79  3010787.99
# 23672 2017-07-01 12:00:00  ETHUSD  275.01  275.01  271.00  274.83   824362.87
# 23673 2017-07-01 11:00:00  ETHUSD  279.98  279.99  272.10  275.01   679358.87
#
# [23674 rows x 7 columns]

# %%
df["Date"].dt.day_name()
# Out:
# 0          Friday
# 1          Friday
# 2          Friday
# 3          Friday
# 4          Friday
#            ...
# 23669    Saturday
# 23670    Saturday
# 23671    Saturday
# 23672    Saturday
# 23673    Saturday
# Name: Date, Length: 23674, dtype: object

# %%
df["Date"].dt.day_name()
# Out:
# 0          Friday
# 1          Friday
# 2          Friday
# 3          Friday
# 4          Friday
#            ...
# 23669    Saturday
# 23670    Saturday
# 23671    Saturday
# 23672    Saturday
# 23673    Saturday
# Name: Date, Length: 23674, dtype: object

# %%
df["Days_ofWeek"]=df["Date"].dt.day_name()

# %%
df
# Out:
#                      Date  Symbol    Open    High     Low   Close      Volume  \
# 0     2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1     2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2     2020-03-13 18:00:00  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3     2020-03-13 17:00:00  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4     2020-03-13 16:00:00  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ...                   ...     ...     ...     ...     ...     ...         ...
# 23669 2017-07-01 15:00:00  ETHUSD  265.74  272.74  265.00  272.57  1500282.55
# 23670 2017-07-01 14:00:00  ETHUSD  268.79  269.90  265.00  265.74  1702536.85
# 23671 2017-07-01 13:00:00  ETHUSD  274.83  274.93  265.00  268.79  3010787.99
# 23672 2017-07-01 12:00:00  ETHUSD  275.01  275.01  271.00  274.83   824362.87
# 23673 2017-07-01 11:00:00  ETHUSD  279.98  279.99  272.10  275.01   679358.87
#
#       Days_ofWeek
# ...

# %%
df["Date"].max()
# Out:
# Timestamp('2020-03-13 20:00:00')

# %%
df["Date"].min()
# Out:
# Timestamp('2017-07-01 11:00:00')

# %%
df.loc[0,"Date"]-df.loc[227,"Date"]
# Out:
# Timedelta('9 days 11:00:00')

# %%
filt=df["Date"]>="2020"

# %%
df[filt]
# Out:
#                     Date  Symbol    Open    High     Low   Close      Volume  \
# 0    2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1    2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2    2020-03-13 18:00:00  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3    2020-03-13 17:00:00  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4    2020-03-13 16:00:00  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ...                  ...     ...     ...     ...     ...     ...         ...
# 1744 2020-01-01 04:00:00  ETHUSD  129.57  130.00  129.50  129.56   702786.82
# 1745 2020-01-01 03:00:00  ETHUSD  130.37  130.44  129.38  129.57   496704.23
# 1746 2020-01-01 02:00:00  ETHUSD  130.14  130.50  129.91  130.37   396315.72
# 1747 2020-01-01 01:00:00  ETHUSD  128.34  130.14  128.32  130.14   635419.40
# 1748 2020-01-01 00:00:00  ETHUSD  128.54  128.54  128.12  128.34   245119.91
#
#      Days_ofWeek
# 0         Friday
# ...

# %%
filt=(df["Date"]>="2019") & (df["Date"]<="2020")

# %%
df[filt]
# Out:
#                      Date  Symbol    Open    High     Low   Close      Volume  \
# 1748  2020-01-01 00:00:00  ETHUSD  128.54  128.54  128.12  128.34   245119.91
# 1749  2019-12-31 23:00:00  ETHUSD  128.33  128.69  128.14  128.54   440678.91
# 1750  2019-12-31 22:00:00  ETHUSD  128.38  128.69  127.95  128.33   554646.02
# 1751  2019-12-31 21:00:00  ETHUSD  127.86  128.43  127.72  128.38   350155.69
# 1752  2019-12-31 20:00:00  ETHUSD  127.84  128.34  127.71  127.86   428183.38
# ...                   ...     ...     ...     ...     ...     ...         ...
# 10504 2019-01-01 04:00:00  ETHUSD  130.75  133.96  130.74  131.96  2791135.37
# 10505 2019-01-01 03:00:00  ETHUSD  130.06  130.79  130.06  130.75   503732.63
# 10506 2019-01-01 02:00:00  ETHUSD  130.79  130.88  129.55  130.06   838183.43
# 10507 2019-01-01 01:00:00  ETHUSD  131.62  131.62  130.77  130.79   434917.99
# 10508 2019-01-01 00:00:00  ETHUSD  130.53  131.91  130.48  131.62  1067136.21
#
#       Days_ofWeek
# ...

# %%
filt=(df["Date"]>=pd.to_datetime("2019-01-01")) & (df["Date"]<=pd.to_datetime("2020-01-01"))

# %%
df[filt]
# Out:
#                      Date  Symbol    Open    High     Low   Close      Volume  \
# 1748  2020-01-01 00:00:00  ETHUSD  128.54  128.54  128.12  128.34   245119.91
# 1749  2019-12-31 23:00:00  ETHUSD  128.33  128.69  128.14  128.54   440678.91
# 1750  2019-12-31 22:00:00  ETHUSD  128.38  128.69  127.95  128.33   554646.02
# 1751  2019-12-31 21:00:00  ETHUSD  127.86  128.43  127.72  128.38   350155.69
# 1752  2019-12-31 20:00:00  ETHUSD  127.84  128.34  127.71  127.86   428183.38
# ...                   ...     ...     ...     ...     ...     ...         ...
# 10504 2019-01-01 04:00:00  ETHUSD  130.75  133.96  130.74  131.96  2791135.37
# 10505 2019-01-01 03:00:00  ETHUSD  130.06  130.79  130.06  130.75   503732.63
# 10506 2019-01-01 02:00:00  ETHUSD  130.79  130.88  129.55  130.06   838183.43
# 10507 2019-01-01 01:00:00  ETHUSD  131.62  131.62  130.77  130.79   434917.99
# 10508 2019-01-01 00:00:00  ETHUSD  130.53  131.91  130.48  131.62  1067136.21
#
#       Days_ofWeek
# ...

# %%
df.set_index("Date",inplace=True)

# %%
df
# Out:
#                      Symbol    Open    High     Low   Close      Volume  \
# Date
# 2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2020-03-13 18:00:00  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 2020-03-13 17:00:00  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 2020-03-13 16:00:00  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ...                     ...     ...     ...     ...     ...         ...
# 2017-07-01 15:00:00  ETHUSD  265.74  272.74  265.00  272.57  1500282.55
# 2017-07-01 14:00:00  ETHUSD  268.79  269.90  265.00  265.74  1702536.85
# 2017-07-01 13:00:00  ETHUSD  274.83  274.93  265.00  268.79  3010787.99
# 2017-07-01 12:00:00  ETHUSD  275.01  275.01  271.00  274.83   824362.87
# 2017-07-01 11:00:00  ETHUSD  279.98  279.99  272.10  275.01   679358.87
#
#                     Days_ofWeek
# Date
# 2020-03-13 20:00:00      Friday
# ...

# %%
df.loc["2019"]
# Out:
#                      Symbol    Open    High     Low   Close      Volume  \
# Date
# 2019-12-31 23:00:00  ETHUSD  128.33  128.69  128.14  128.54   440678.91
# 2019-12-31 22:00:00  ETHUSD  128.38  128.69  127.95  128.33   554646.02
# 2019-12-31 21:00:00  ETHUSD  127.86  128.43  127.72  128.38   350155.69
# 2019-12-31 20:00:00  ETHUSD  127.84  128.34  127.71  127.86   428183.38
# 2019-12-31 19:00:00  ETHUSD  128.69  128.69  127.60  127.84  1169847.84
# ...                     ...     ...     ...     ...     ...         ...
# 2019-01-01 04:00:00  ETHUSD  130.75  133.96  130.74  131.96  2791135.37
# 2019-01-01 03:00:00  ETHUSD  130.06  130.79  130.06  130.75   503732.63
# 2019-01-01 02:00:00  ETHUSD  130.79  130.88  129.55  130.06   838183.43
# 2019-01-01 01:00:00  ETHUSD  131.62  131.62  130.77  130.79   434917.99
# 2019-01-01 00:00:00  ETHUSD  130.53  131.91  130.48  131.62  1067136.21
#
#                     Days_ofWeek
# Date
# 2019-12-31 23:00:00     Tuesday
# ...

# %%
df.loc["2020-01":"2020-02"]["Close"]
# Out:
# Date
# 2020-02-29 23:00:00    217.31
# 2020-02-29 22:00:00    223.35
# 2020-02-29 21:00:00    223.48
# 2020-02-29 20:00:00    224.63
# 2020-02-29 19:00:00    225.31
#                         ...
# 2020-01-01 04:00:00    129.56
# 2020-01-01 03:00:00    129.57
# 2020-01-01 02:00:00    130.37
# 2020-01-01 01:00:00    130.14
# 2020-01-01 00:00:00    128.34
# Name: Close, Length: 1440, dtype: float64

# %%
df.loc["2020-01":"2020-02"]["Close"].mean()
# Out:
# 195.16559027777814

# %%
df["High"].resample("w")

# %%
highs = df['High'].resample('D').max()

# %%
highs
# Out:
# Date
# 2017-07-01    279.99
# 2017-07-02    293.73
# 2017-07-03    285.00
# 2017-07-04    282.83
# 2017-07-05    274.97
#                ...
# 2020-03-09    208.65
# 2020-03-10    206.28
# 2020-03-11    202.98
# 2020-03-12    195.64
# 2020-03-13    148.00
# Freq: D, Name: High, Length: 987, dtype: float64

# %%
highs['2020-01-01']
# Out:
# 132.68

# %%
highs = df['High'].resample('w').max()

# %%
# %matplotlib inline

# %%
highs.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df.resample("w").agg({"Close":"mean","Low":"min","Volume":"sum","High":"max"})
# Out:
#                  Close     Low        Volume    High
# Date
# 2017-07-02  268.202162  253.23  8.084631e+07  293.73
# 2017-07-09  261.062083  231.25  2.246746e+08  285.00
# 2017-07-16  195.698393  130.26  5.017750e+08  240.33
# 2017-07-23  212.783750  153.25  7.221637e+08  249.40
# 2017-07-30  203.309524  178.03  2.657305e+08  229.99
# ...                ...     ...           ...     ...
# 2020-02-16  255.198452  216.31  3.912867e+08  290.00
# 2020-02-23  265.321905  242.36  3.067838e+08  287.13
# 2020-03-01  236.373988  209.26  3.693920e+08  278.13
# 2020-03-08  229.817619  196.00  2.736569e+08  253.01
# 2020-03-15  176.332821   90.00  4.983998e+08  208.65
#
# [142 rows x 4 columns]

# %%
df["High"].resample("w").max()
# Out:
# Date
# 2017-07-02    293.73
# 2017-07-09    285.00
# 2017-07-16    240.33
# 2017-07-23    249.40
# 2017-07-30    229.99
#                ...
# 2020-02-16    290.00
# 2020-02-23    287.13
# 2020-03-01    278.13
# 2020-03-08    253.01
# 2020-03-15    208.65
# Freq: W-SUN, Name: High, Length: 142, dtype: float64

# %%
df["High"].resample("w").max().loc["2017-07-03 ":"2017-07-11 "]
# Out:
# Date
# 2017-07-09    285.0
# Freq: W-SUN, Name: High, dtype: float64

# %%
df.resample("w").max()
# Out:
#             Symbol    Open    High     Low   Close       Volume Days_ofWeek
# Date
# 2017-07-02  ETHUSD  292.54  293.73  284.87  292.54   7081816.11      Sunday
# 2017-07-09  ETHUSD  285.00  285.00  282.31  282.58   6082287.50   Wednesday
# 2017-07-16  ETHUSD  238.81  240.33  238.00  238.47  23582117.48   Wednesday
# 2017-07-23  ETHUSD  245.55  249.40  234.97  245.55  31082353.62   Wednesday
# 2017-07-30  ETHUSD  229.96  229.99  229.60  229.96   9214814.73   Wednesday
# ...            ...     ...     ...     ...     ...          ...         ...
# 2020-02-16  ETHUSD  286.39  290.00  285.10  286.39  13323454.31   Wednesday
# 2020-02-23  ETHUSD  285.30  287.13  282.00  285.30  12085035.32   Wednesday
# 2020-03-01  ETHUSD  276.91  278.13  274.28  276.91  19074673.60   Wednesday
# 2020-03-08  ETHUSD  247.62  253.01  245.01  247.62   8804126.61   Wednesday
# 2020-03-15  ETHUSD  207.79  208.65  205.83  207.79  19731142.71   Wednesday
#
# [142 rows x 7 columns]

# %%
df.resample("w").agg({"Close":"mean","Low":"min","Volume":"sum"})
# Out:
#                  Close     Low        Volume
# Date
# 2017-07-02  268.202162  253.23  8.084631e+07
# 2017-07-09  261.062083  231.25  2.246746e+08
# 2017-07-16  195.698393  130.26  5.017750e+08
# 2017-07-23  212.783750  153.25  7.221637e+08
# 2017-07-30  203.309524  178.03  2.657305e+08
# ...                ...     ...           ...
# 2020-02-16  255.198452  216.31  3.912867e+08
# 2020-02-23  265.321905  242.36  3.067838e+08
# 2020-03-01  236.373988  209.26  3.693920e+08
# 2020-03-08  229.817619  196.00  2.736569e+08
# 2020-03-15  176.332821   90.00  4.983998e+08
#
# [142 rows x 3 columns]

# %%
import pandas as pd
import math
import numpy as np
df=pd.read_csv("ETH_1h.csv")

# %%
import datetime
df["Date"].apply(lambda x: datetime.datetime.strptime(x,"%Y-%m-%d %I-%p"))
# Out:
# 0       2020-03-13 20:00:00
# 1       2020-03-13 19:00:00
# 2       2020-03-13 18:00:00
# 3       2020-03-13 17:00:00
# 4       2020-03-13 16:00:00
#                 ...
# 23669   2017-07-01 15:00:00
# 23670   2017-07-01 14:00:00
# 23671   2017-07-01 13:00:00
# 23672   2017-07-01 12:00:00
# 23673   2017-07-01 11:00:00
# Name: Date, Length: 23674, dtype: datetime64[ns]
